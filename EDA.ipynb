# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaMaitra/PRODIGY_DS_02/blob/master/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
data = pd.read_csv('Mortality.csv')

# %% [markdown]
# # Exploring the dataset

# %%
data.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# 2     16.100        76.5       2.89   4460
# ...

# %%
data.duplicated().sum()
data.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# # Handle missing values:

# %%
data.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# 2     16.100        76.5       2.89   4460
# ...

# %%
data.describe() # get summary statistics
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %% [markdown]
# # **EDA**

# %% [markdown]
# Top 10 countries with highest child mortality rate

# %%
data.sort_values('child_mort',ascending=False).head(10)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 97                       Mali       137.0     22.8    4.98     35.1    1870
# 113                   Nigeria       130.0     25.3    5.07     17.4    5150
# 112                     Niger       123.0     22.2    5.16     49.1     814
# 3                      Angola       119.0     62.3    2.85     42.9    5900
# 25               Burkina Faso       116.0     19.2    6.74     29.6    1430
# 37           Congo, Dem. Rep.       116.0     41.1    7.91     49.6     609
#
#      inflation  life_expec  total_fer  gdpp
# 66        5.45        32.1       3.33   662
# ...

# %% [markdown]
# Top 10 countries with the highest GDP

# %%
data.sort_values('gdpp',ascending=False).head(10)
# Out:
#            country  child_mort  exports  health  imports  income  inflation  \
# 91      Luxembourg         2.8    175.0    7.77    142.0   91700      3.620
# 114         Norway         3.2     39.7    9.48     28.5   62300      5.950
# 145    Switzerland         4.5     64.0   11.50     53.3   55500      0.317
# 123          Qatar         9.0     62.3    1.81     23.8  125000      6.980
# 44         Denmark         4.1     50.5   11.40     43.6   44000      3.220
# 144         Sweden         3.0     46.2    9.63     40.7   42900      0.991
# 7        Australia         4.8     19.8    8.73     20.9   41400      1.160
# 110    Netherlands         4.5     72.0   11.90     63.6   45500      0.848
# 73         Ireland         4.2    103.0    9.19     86.5   45700     -3.220
# 159  United States         7.3     12.4   17.90     15.8   49400      1.220
#
#      life_expec  total_fer    gdpp
# 91         81.3       1.63  105000
# 114        81.0       1.95   87800
# ...

# %% [markdown]
# Top 10 countries with the highest inflation rate

# %%
data.sort_values('inflation',ascending=False).head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 113            Nigeria       130.0     25.3    5.07     17.4    5150
# 163          Venezuela        17.1     28.5    4.91     17.6   16500
# 103           Mongolia        26.1     46.7    5.44     56.7    7710
# 149        Timor-Leste        62.6      2.2    9.12     27.8    1850
# 49   Equatorial Guinea       111.0     85.8    4.48     58.9   33700
# 165              Yemen        56.3     30.0    5.18     34.4    4480
# 140          Sri Lanka        11.2     19.6    2.94     26.8    8560
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 37    Congo, Dem. Rep.       116.0     41.1    7.91     49.6     609
#
#      inflation  life_expec  total_fer   gdpp
# 113      104.0        60.5       5.84   2330
# 163       45.9        75.4       2.47  13500
# 103       39.2        66.2       2.64   2650
# ...

# %% [markdown]
# Top 10 countries with the highest life expectency

# %%
data.sort_values('life_expec',ascending=False).head(10)
# Out:
#          country  child_mort  exports  health  imports  income  inflation  \
# 77         Japan         3.2     15.0    9.49     13.6   35800     -1.900
# 133    Singapore         2.8    200.0    3.96    174.0   72100     -0.046
# 145  Switzerland         4.5     64.0   11.50     53.3   55500      0.317
# 68       Iceland         2.6     53.4    9.40     43.3   38800      5.470
# 7      Australia         4.8     19.8    8.73     20.9   41400      1.160
# 139        Spain         3.8     25.5    9.54     26.8   32500      0.160
# 75         Italy         4.0     25.2    9.53     27.2   36200      0.319
# 144       Sweden         3.0     46.2    9.63     40.7   42900      0.991
# 74        Israel         4.6     35.0    7.63     32.9   29600      1.770
# 54        France         4.2     26.8   11.90     28.1   36900      1.050
#
#      life_expec  total_fer   gdpp
# 77         82.8       1.39  44500
# 133        82.7       1.15  46600
# 145        82.2       1.52  74600
# ...

# %% [markdown]
# Top 10 countries with the lowest life expectency

# %%
data.sort_values('life_expec',ascending=True).head(10)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 87                    Lesotho        99.7     39.4   11.10    101.0    2380
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 166                    Zambia        83.1     37.0    5.89     30.9    3280
# 94                     Malawi        90.5     22.8    6.59     34.9    1030
# 137              South Africa        53.7     28.6    8.94     27.4   12000
# 106                Mozambique       101.0     31.5    5.21     46.2     918
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 64              Guinea-Bissau       114.0     14.9    8.50     35.2    1390
# 0                 Afghanistan        90.2     10.0    7.58     44.9    1610
#
#      inflation  life_expec  total_fer  gdpp
# 66        5.45        32.1       3.33   662
# ...

# %% [markdown]
# Top 10 countries with the highest avg income

# %%
data.sort_values('income',ascending=False).head(10)
# Out:
#                   country  child_mort  exports  health  imports  income  \
# 123                 Qatar         9.0     62.3    1.81     23.8  125000
# 91             Luxembourg         2.8    175.0    7.77    142.0   91700
# 23                 Brunei        10.5     67.4    2.84     28.0   80600
# 82                 Kuwait        10.8     66.7    2.63     30.4   75200
# 133             Singapore         2.8    200.0    3.96    174.0   72100
# 114                Norway         3.2     39.7    9.48     28.5   62300
# 157  United Arab Emirates         8.6     77.7    3.66     63.6   57600
# 145           Switzerland         4.5     64.0   11.50     53.3   55500
# 159         United States         7.3     12.4   17.90     15.8   49400
# 73                Ireland         4.2    103.0    9.19     86.5   45700
#
#      inflation  life_expec  total_fer    gdpp
# 123      6.980        79.5       2.07   70300
# 91       3.620        81.3       1.63  105000
# ...

# %% [markdown]
# **Converting metrics into percentages WRT GDP**

# %%
data.exports = (data.exports*data.gdpp)/100
data.imports = (data.imports*data.gdpp)/100
data.health = (data.health*data.gdpp)/100

data.head(10)
# Out:
#                country  child_mort   exports     health    imports  income  \
# 0          Afghanistan        90.2     55.30    41.9174    248.297    1610
# 1              Albania        16.6   1145.20   267.8950   1987.740    9930
# 2              Algeria        27.3   1712.64   185.9820   1400.440   12900
# 3               Angola       119.0   2199.19   100.6050   1514.370    5900
# 4  Antigua and Barbuda        10.3   5551.00   735.6600   7185.800   19100
# 5            Argentina        14.5   1946.70   834.3000   1648.000   18700
# 6              Armenia        18.1    669.76   141.6800   1458.660    6700
# 7            Australia         4.8  10276.20  4530.8700  10847.100   41400
# 8              Austria         4.3  24059.70  5159.0000  22418.200   43200
# 9           Azerbaijan        39.2   3171.12   343.3920   1208.880   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# ...

# %% [markdown]
# Top 10 countries wth highest exports

# %%
data.sort_values('exports',ascending=False).head(10)
# Out:
#          country  child_mort   exports   health   imports  income  inflation  \
# 91    Luxembourg         2.8  183750.0  8158.50  149100.0   91700      3.620
# 133    Singapore         2.8   93200.0  1845.36   81084.0   72100     -0.046
# 73       Ireland         4.2   50161.0  4475.53   42125.5   45700     -3.220
# 145  Switzerland         4.5   47744.0  8579.00   39761.8   55500      0.317
# 123        Qatar         9.0   43796.9  1272.43   16731.4  125000      6.980
# 110  Netherlands         4.5   36216.0  5985.70   31990.8   45500      0.848
# 114       Norway         3.2   34856.6  8323.44   25023.0   62300      5.950
# 15       Belgium         4.5   33921.6  4750.80   33166.8   41100      1.880
# 98         Malta         6.8   32283.0  1825.15   32494.0   28300      3.830
# 44       Denmark         4.1   29290.0  6612.00   25288.0   44000      3.220
#
#      life_expec  total_fer    gdpp
# 91         81.3       1.63  105000
# 133        82.7       1.15   46600
# ...

# %% [markdown]
# Top 10 countries wth lowest imports

# %%
data.sort_values('imports',ascending=True).head(10)
# Out:
#                       country  child_mort    exports   health     imports  \
# 107                   Myanmar        64.4    1.07692  19.4636    0.651092
# 26                    Burundi        93.6   20.60520  26.7960   90.552000
# 50                    Eritrea        55.2   23.08780  12.8212  112.306000
# 31   Central African Republic       149.0   52.62800  17.7508  118.190000
# 132              Sierra Leone       160.0   67.03200  52.2690  137.655000
# 94                     Malawi        90.5  104.65200  30.2481  160.191000
# 12                 Bangladesh        49.4  121.28000  26.6816  165.244000
# 37           Congo, Dem. Rep.       116.0  137.27400  26.4194  165.664000
# 126                    Rwanda        63.6   67.56000  59.1150  168.900000
# 155                    Uganda        81.0  101.74500  53.6095  170.170000
#
#      income  inflation  life_expec  total_fer  gdpp
# 107    3720       7.04        66.8       2.41   988
# ...

# %% [markdown]
# Top 10 countries that are very low on health index

# %%
data.sort_values('health',ascending=True).head(10)
# Out:
#                       country  child_mort    exports   health     imports  \
# 50                    Eritrea        55.2   23.08780  12.8212  112.306000
# 93                 Madagascar        62.2  103.25000  15.5701  177.590000
# 31   Central African Republic       149.0   52.62800  17.7508  118.190000
# 112                     Niger       123.0   77.25600  17.9568  170.868000
# 107                   Myanmar        64.4    1.07692  19.4636    0.651092
# 106                Mozambique       101.0  131.98500  21.8299  193.578000
# 116                  Pakistan        92.1  140.40000  22.8800  201.760000
# 37           Congo, Dem. Rep.       116.0  137.27400  26.4194  165.664000
# 12                 Bangladesh        49.4  121.28000  26.6816  165.244000
# 26                    Burundi        93.6   20.60520  26.7960   90.552000
#
#      income  inflation  life_expec  total_fer  gdpp
# 50     1420      11.60        61.7       4.61   482
# ...

# %% [markdown]
# # Exploring The Correlation

# %%
data = data.drop(columns=['country']) # dropping country column for better graphic representation

# %% [markdown]
# Creating pair plot for the data givem

# %%
sns.pairplot(data)

# %% [markdown]
# Exploring the correaltion

# %%
data.corr()
# Out:
#             child_mort   exports    health   imports    income  inflation  \
# child_mort    1.000000 -0.297230 -0.430438 -0.319138 -0.524315   0.288276
# exports      -0.297230  1.000000  0.612919  0.987686  0.725351  -0.141553
# health       -0.430438  0.612919  1.000000  0.638581  0.690857  -0.253956
# imports      -0.319138  0.987686  0.638581  1.000000  0.672056  -0.179458
# income       -0.524315  0.725351  0.690857  0.672056  1.000000  -0.147756
# inflation     0.288276 -0.141553 -0.253956 -0.179458 -0.147756   1.000000
# life_expec   -0.886676  0.377694  0.545626  0.397515  0.611962  -0.239705
# total_fer     0.848478 -0.291096 -0.407984 -0.317061 -0.501840   0.316921
# gdpp         -0.483032  0.768894  0.916593  0.755114  0.895571  -0.221631
#
#             life_expec  total_fer      gdpp
# child_mort   -0.886676   0.848478 -0.483032
# exports       0.377694  -0.291096  0.768894
# health        0.545626  -0.407984  0.916593
# imports       0.397515  -0.317061  0.755114
# ...

# %% [markdown]
# Creating the heatmap

# %%
sns.heatmap(data.corr(),annot=True,cmap='rocket')
# Out:
# <Axes: >

# %% [markdown]
# **The highest correlations are between : **<br>
#
# imports & exports (0.99) <br>
# health & gdpp (0.92) <br>
# income & gdpp (0.9)<br>
# total fertility & child mortality (0.85) <br>

# %% [markdown]
# **The lowest correlations are between :** <br>
#
# life expectancy & child mortality (-0.89) <br>
# total fertility & life expectancy (-0.76) <br>
